# %% [markdown]
# # Task 1: Basic DataFrame Operations
# Create a DataFrame with student data:
#
# Name, Age, City, Math Score, Science Score
#
# Select only the Math Score column.
#
# Filter students who scored above 80 in Science.
#
# Add a new column Average Score as the mean of Math & Science.
#
# Sort students by Average Score descending.

# %%
import pandas as pd
import numpy as np

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
    'Age': [25, 27, 30, 35, 28],
    'City': ['Cairo', 'Paris', "Paris", 'London', 'Paris'],
    'Math Score': [100, 60, 67, 85, 98],
    'Science Score': [82, 60, 63, 45, 28]
}

df = pd.DataFrame(data)
df
# Out:
#       Name  Age    City  Math Score  Science Score
# 0    Alice   25   Cairo         100             82
# 1      Bob   27   Paris          60             60
# 2  Charlie   30   Paris          67             63
# 3    David   35  London          85             45
# 4      Eva   28   Paris          98             28

# %%
df['Math Score']
# Out:
# 0    100
# 1     60
# 2     67
# 3     85
# 4     98
# Name: Math Score, dtype: int64

# %%
df[df['Science Score'] > 80]
# Out:
#     Name  Age   City  Math Score  Science Score
# 0  Alice   25  Cairo         100             82

# %%
df['avg'] = (df['Science Score'] + df['Math Score']) / 2

# %%
df
# Out:
#       Name  Age    City  Math Score  Science Score   avg
# 0    Alice   25   Cairo         100             82  91.0
# 1      Bob   27   Paris          60             60  60.0
# 2  Charlie   30   Paris          67             63  65.0
# 3    David   35  London          85             45  65.0
# 4      Eva   28   Paris          98             28  63.0

# %%
df.sort_values('avg', ascending=False)
# Out:
#       Name  Age    City  Math Score  Science Score   avg
# 0    Alice   25   Cairo         100             82  91.0
# 2  Charlie   30   Paris          67             63  65.0
# 3    David   35  London          85             45  65.0
# 4      Eva   28   Paris          98             28  63.0
# 1      Bob   27   Paris          60             60  60.0

# %% [markdown]
# # Task 2: Missing Data
# You are given this dataset:
#
#
# data = {
#     'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
#     'Age': [25, np.nan, 30, np.nan, 28],
#     'City': ['Cairo', 'Paris', None, 'London', 'Paris'],
#     'Salary': [5000, 6000, None, 5500, 5800]
# }
#
#
# Find how many missing values are in each column.
#
# Fill missing Age with the average Age.
#
# Fill missing City with "Unknown".
#
# Drop any rows where Salary is missing.

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
    'Age': [25, np.nan, 30, np.nan, 28],
    'City': ['Cairo', 'Paris', None, 'London', 'Paris'],
    'Salary': [5000, 6000, None, 5500, 5800]
}
df2 = pd.DataFrame(data)

# %%
df2
# Out:
#       Name   Age    City  Salary
# 0    Alice  25.0   Cairo  5000.0
# 1      Bob   NaN   Paris  6000.0
# 2  Charlie  30.0    None     NaN
# 3    David   NaN  London  5500.0
# 4      Eva  28.0   Paris  5800.0

# %%
df2.isna().sum()
# Out:
# Name      0
# Age       2
# City      1
# Salary    1
# dtype: int64

# %%
df2['Age'].mean()
# Out:
# np.float64(27.666666666666668)

# %%
df2['Age'] = df2['Age'].fillna(df2['Age'].mean())

# %%
df2['Age'] = df2['Age'].apply(lambda x: round(x))

# %%
df2
# Out:
#       Name  Age    City  Salary
# 0    Alice   25   Cairo  5000.0
# 1      Bob   28   Paris  6000.0
# 2  Charlie   30    None     NaN
# 3    David   28  London  5500.0
# 4      Eva   28   Paris  5800.0

# %%
df2['City'] = df2['City'].fillna('Unknown')

# %%
df2
# Out:
#       Name  Age     City  Salary
# 0    Alice   25    Cairo  5000.0
# 1      Bob   28    Paris  6000.0
# 2  Charlie   30  Unknown     NaN
# 3    David   28   London  5500.0
# 4      Eva   28    Paris  5800.0

# %%
df2 = df2.dropna(subset=['Salary'])

# %%
df2
# Out:
#     Name  Age    City  Salary
# 0  Alice   25   Cairo  5000.0
# 1    Bob   28   Paris  6000.0
# 3  David   28  London  5500.0
# 4    Eva   28   Paris  5800.0

# %%
df2 = df2.reset_index(drop=True)

# %%
df2
# Out:
#     Name  Age    City  Salary
# 0  Alice   25   Cairo  5000.0
# 1    Bob   28   Paris  6000.0
# 2  David   28  London  5500.0
# 3    Eva   28   Paris  5800.0
